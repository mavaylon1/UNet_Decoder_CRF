# %%
from keras.layers import *
from keras.models import Model
from keras import layers
from keras.layers.merge import concatenate
import sys
sys.path.insert(1, '../src')
sys.path.insert(1, '../image_segmentation_keras')
from keras_segmentation.models.config import IMAGE_ORDERING

from keras_segmentation.models.model_utils import get_segmentation_model
from glob import glob
from crfrnn_layer import CrfRnnLayer

# %%
input_height = 256
input_width = 256
n_classes = 3
channels = 3

# %%
def unet_conv_block(inputs, filters, pool=True, batch_norm_first=True):
    if batch_norm_first == True:
        x = Conv2D(filters, 3, padding="same")(inputs)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)

        x = Conv2D(filters, 3, padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    elif batch_norm_first == False:
        x = Conv2D(filters, 3, padding="same")(inputs)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)

        x = Conv2D(filters, 3, padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)

    if pool == True:
        p = MaxPooling2D((2, 2))(x)
        return [x, p]
    else:
        return x

# %%
img_input = Input(shape=(input_height,input_width, channels))
x1 = Conv2D(64, 3, padding="same")(img_input)
x1 = BatchNormalization()(x1)
x1 = Activation("relu")(x1)

x1 = Conv2D(64, 3, padding="same")(x1)
x1 = BatchNormalization()(x1)
x1 = Activation("relu")(x1)

p1 = MaxPooling2D((2, 2))(x1)
###########################
x2 = Conv2D(128, 3, padding="same")(p1)
x2 = BatchNormalization()(x2)
x2 = Activation("relu")(x2)

x2 = Conv2D(128, 3, padding="same")(x2)
x2 = BatchNormalization()(x2)
x2 = Activation("relu")(x2)

p2 = MaxPooling2D((2, 2))(x2)
###########################
x3 = Conv2D(256, 3, padding="same")(p2)
x3 = BatchNormalization()(x3)
x3 = Activation("relu")(x3)

x3 = Conv2D(256, 3, padding="same")(x3)
x3 = BatchNormalization()(x3)
x3 = Activation("relu")(x3)
###########################
x4 = UpSampling2D((2, 2))(x3)
x4 = concatenate([x4, x2], axis=3)

x4 = Conv2D(128, 3, padding="same")(x4)
x4 = BatchNormalization()(x4)
x4 = Activation("relu")(x4)

x4 = Conv2D(128, 3, padding="same")(x4)
x4 = BatchNormalization()(x4)
x4 = Activation("relu")(x4)
###########################
crf_mid = CrfRnnLayer(image_dims=(128, 128),
                         num_classes=128,
                         theta_alpha=160.,
                         theta_beta=3.,
                         theta_gamma=3.,
                         num_iterations=10,
                         name='crfrnn')([x4, x2])
###########################
x5 = UpSampling2D((2, 2))(x4)
x5 = concatenate([x5, x1], axis=3)

x5 = Conv2D(64, 3, padding="same")(x5)
x5 = BatchNormalization()(x5)
x5 = Activation("relu")(x5)

x5 = Conv2D(64, 3, padding="same")(x5)
x5 = BatchNormalization()(x5)
x5 = Activation("relu")(x5)

x5 = Conv2D(n_classes, (1,1), padding='same')(x5)
x5 = BatchNormalization()(x5)

crf_output = CrfRnnLayer(image_dims=(input_height, input_width),
                         num_classes=3,
                         theta_alpha=160.,
                         theta_beta=3.,
                         theta_gamma=3.,
                         num_iterations=10,
                         name='crfrnn')([x5, img_input])
model = get_segmentation_model(img_input, crf_output)

# %%
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 64) 1792        input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 256, 256, 64) 256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 256, 256, 64) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 256, 256, 64) 36928       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 256, 256, 64) 256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 256, 256, 64) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 128 73856       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 128, 128, 128 512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 128, 128, 128 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 128 147584      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 128, 128, 128 512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 128, 128, 128 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 64, 64, 128)  0           activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 256)  295168      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64, 64, 256)  1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 64, 64, 256)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 256)  590080      activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 64, 64, 256)  1024        conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 64, 64, 256)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 256 0           activation_41[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 384 0           up_sampling2d_7[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 128 442496      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 128, 128, 128 512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 128, 128, 128 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 128 147584      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 128, 128, 128 512         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 128, 128, 128 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 256, 256, 128 0           activation_43[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 192 0           up_sampling2d_8[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 256, 256, 64) 110656      concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 256, 256, 64) 256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 256, 256, 64) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 256, 256, 64) 36928       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 256, 256, 64) 256         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 256, 256, 64) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 256, 256, 3)  195         activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 256, 256, 3)  12          conv2d_48[0][0]
# __________________________________________________________________________________________________
# crfrnn (CrfRnnLayer)            [(None, 256, 256, 3) 27          batch_normalization_46[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 65536, 3)     0           crfrnn[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 65536, 3)     0           reshape_2[0][0]
# ==================================================================================================
# Total params: 1,888,426
# Trainable params: 1,885,860
# Non-trainable params: 2,566
# __________________________________________________________________________________________________

# %%
model.train(
    train_images =  "/Users/mavaylon/Research/Data1/train/img/",
    train_annotations = "/Users/mavaylon/Research/Data1/train/ann/",
    epochs=20,
    steps_per_epoch=len(glob("/Users/mavaylon/Research/Data1/train/img/*")),
    batch_size=1,
    validate=True,
    val_images="/Users/mavaylon/Research/Data1/test/img/",
    val_annotations="/Users/mavaylon/Research/Data1/test/ann/",
    val_batch_size=1,
    val_steps_per_epoch=len(glob("/Users/mavaylon/Research/Data1/test/img/*"))
)
# Out:
# Verifying training dataset
#  55%|█████▌    | 3254/5912 [00:21<00:17, 154.16it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f40a9c090d4b> in <module>
#       9     val_annotations="/Users/mavaylon/Research/Data1/test/ann/",
#      10     val_batch_size=1,
# ---> 11     val_steps_per_epoch=len(glob("/Users/mavaylon/Research/Data1/test/img/*"))
#      12 )
#
# ~/Research/CNN_CRF/LBNL_Segmentation_crf/image_segmentation_keras/keras_segmentation/train.py in train(model, train_images, train_annotations, input_height, input_width, n_classes, verify_dataset, checkpoints_path, epochs, batch_size, validate, val_images, val_annotations, val_batch_size, auto_resume_checkpoint, load_weights, steps_per_epoch, val_steps_per_epoch, gen_use_multiprocessing, ignore_zero_class, optimizer_name, do_augment, augmentation_name, callbacks, custom_augmentation, other_inputs_paths, preprocessing, read_image_type)
#     157         verified = verify_segmentation_dataset(train_images,
#     158                                                train_annotations,
# --> 159                                                n_classes)
#     160         assert verified
#     161         if validate:
#
# ~/Research/CNN_CRF/LBNL_Segmentation_crf/image_segmentation_keras/keras_segmentation/data_utils/data_loader.py in verify_segmentation_dataset(images_path, segs_path, n_classes, show_all_errors)
#     213         return_value = True
#     214         for im_fn, seg_fn in tqdm(img_seg_pairs):
# --> 215             img = cv2.imread(im_fn)
#     216             seg = cv2.imread(seg_fn)
#     217             # Check dimensions match
#
# KeyboardInterrupt:
