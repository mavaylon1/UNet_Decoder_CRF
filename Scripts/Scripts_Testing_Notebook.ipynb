# %%
import sys
sys.path.insert(1, '../Scripts')
from glob import glob
from model_utils import *
from encoders import *
from decoder import *
# Out:
# Using TensorFlow backend.

# %%
from keras.metrics import MeanIoU

# %% [markdown]
# encoder = resnet34_encoder(input_height=512, input_width=512)

# %% [markdown]
# encoder = unet_encoder(input_height=512, input_width=512, filters=[64, 128, 256, 512, 1024], channels=3, batch_norm_first=True)

# %%
encoder = vgg16_encoder(input_height=512, input_width=512, channels=3)

# %% [markdown]
# encoder

# %%
model = unet_decoder(encoder=encoder, input_height=512, input_width=512, n_classes=3, filters=[512, 512, 256, 128, 64], depth=5, transpose=False, batch_norm_first= True, crfrnn_layer=True)

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 512, 512, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 512, 512, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 256, 256, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 256, 256, 128 73856       block1_pool[0][0]
# ...

# %%
# !pip install -U scikit-learn
from sklearn.metrics import f1_score
