# %%
from keras.layers import *
from keras.models import Model
from keras import layers
from keras.layers.merge import concatenate
import sys
sys.path.insert(1, '../src')
sys.path.insert(1, '../image_segmentation_keras')
from keras_segmentation.models.config import IMAGE_ORDERING

from keras_segmentation.models.model_utils import get_segmentation_model
from glob import glob
from crfrnn_layer import CrfRnnLayer
# Out:
# Using TensorFlow backend.

# %%
channels, height, width = 3, 256, 256

# %%
def unet_conv_block(inputs, filters, pool=True, batch_norm_first=True):
    if batch_norm_first == True:
        x = Conv2D(filters, 3, padding="same")(inputs)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)

        x = Conv2D(filters, 3, padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
    elif batch_norm_first == False:
        x = Conv2D(filters, 3, padding="same")(inputs)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)

        x = Conv2D(filters, 3, padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)

    if pool == True:
        p = MaxPooling2D((2, 2))(x)
        return [x, p]
    else:
        return x

# %%
def _unet(n_classes, encoder, l1_skip_conn=True, input_height=416,
          input_width=608):

  
    img_input, levels = encoder(
        input_height=input_height, input_width=input_width)
    [f1, f2, f3, f4, f5, p5] = levels
    
    print("f5",f5.shape)

    x = p5
    
    """ Bridge """
    x = unet_conv_block(x, 1024, pool=False)
    
    x = UpSampling2D((2, 2))(x)
    x = concatenate([x, f5], axis=3)
    x = unet_conv_block(x, 512, pool=False, batch_norm_first=True)
    
    x = UpSampling2D((2, 2))(x)
    x = concatenate([x, f4], axis=3)
    x = unet_conv_block(x, 512, pool=False, batch_norm_first=True)

    x = UpSampling2D((2, 2))(x)
    x = concatenate([x, f3], axis=3)
    x = unet_conv_block(x, 256, pool=False, batch_norm_first=True)

    x = UpSampling2D((2, 2))(x)
    x = concatenate([x, f2], axis=3)
    x = unet_conv_block(x, 128, pool=False, batch_norm_first=True)

    x = UpSampling2D((2, 2))(x)
    x = concatenate([x, f1], axis=3)
    x = unet_conv_block(x, 64, pool=False, batch_norm_first=True)

    x = Conv2D(n_classes, (1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    crf_output = CrfRnnLayer(image_dims=(height, width),
                         num_classes=n_classes,
                         theta_alpha=160.,
                         theta_beta=3.,
                         theta_gamma=3.,
                         num_iterations=10,
                         name='crfrnn')([x, img_input])
    model = get_segmentation_model(img_input, crf_output)

    return model

# %%
if IMAGE_ORDERING == 'channels_first':
    MERGE_AXIS = 1
elif IMAGE_ORDERING == 'channels_last':
    MERGE_AXIS = -1
def get_vgg_encoder(input_height=224,  input_width=224, pretrained='imagenet'):

    assert input_height % 32 == 0
    assert input_width % 32 == 0

    if IMAGE_ORDERING == 'channels_first':
        img_input = Input(shape=(3, input_height, input_width))
    elif IMAGE_ORDERING == 'channels_last':
        img_input = Input(shape=(input_height, input_width, 3))

    x = Conv2D(64, (3, 3), activation='relu', padding='same',
               name='block1_conv1', data_format=IMAGE_ORDERING)(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same',
               name='block1_conv2', data_format=IMAGE_ORDERING)(x)
    p1 = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool',
                     data_format=IMAGE_ORDERING)(x)
    f1 = x
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same',
               name='block2_conv1', data_format=IMAGE_ORDERING)(p1)
    x = Conv2D(128, (3, 3), activation='relu', padding='same',
               name='block2_conv2', data_format=IMAGE_ORDERING)(x)
    p2 = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool',
                     data_format=IMAGE_ORDERING)(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same',
               name='block3_conv1', data_format=IMAGE_ORDERING)(p2)
    x = Conv2D(256, (3, 3), activation='relu', padding='same',
               name='block3_conv2', data_format=IMAGE_ORDERING)(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same',
               name='block3_conv3', data_format=IMAGE_ORDERING)(x)
    p3 = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool',
                     data_format=IMAGE_ORDERING)(x)
    f3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same',
               name='block4_conv1', data_format=IMAGE_ORDERING)(p3)
    x = Conv2D(512, (3, 3), activation='relu', padding='same',
               name='block4_conv2', data_format=IMAGE_ORDERING)(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same',
               name='block4_conv3', data_format=IMAGE_ORDERING)(x)
    p4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool',
                     data_format=IMAGE_ORDERING)(x)
    f4 = x

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same',
               name='block5_conv1', data_format=IMAGE_ORDERING)(p4)
    x = Conv2D(512, (3, 3), activation='relu', padding='same',
               name='block5_conv2', data_format=IMAGE_ORDERING)(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same',
               name='block5_conv3', data_format=IMAGE_ORDERING)(x)
    p5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool',
                     data_format=IMAGE_ORDERING)(x)
    f5 = x

    return img_input, [f1, f2, f3, f4, f5, p5]

# %%
def vgg_unet(n_classes, input_height=416, input_width=608, encoder_level=3):

    model = _unet(n_classes, get_vgg_encoder,
                  input_height=input_height, input_width=input_width)
    model.model_name = "vgg_unet"
    return model

# %%
model = vgg_unet(n_classes=3,input_height=256, input_width=256)
model.summary()
# Out:
# f5 (None, 16, 16, 512)
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 256, 256, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 128, 128, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 128, 128, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 128, 128, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 64, 64, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 64, 64, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 64, 64, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 64, 64, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 32, 32, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 32, 32, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 32, 32, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 32, 32, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 16, 16, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 16, 16, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 16, 16, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 16, 16, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 8, 8, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 1024)   4719616     block5_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 1024)   4096        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 8, 1024)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 1024)   9438208     activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 1024)   4096        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 8, 8, 1024)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 1024) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 1536) 0           up_sampling2d_1[0][0]
#                                                                  block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 512)  7078400     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 512)  2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 512)  2359808     activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 512)  2048        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 512)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 512)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 1024) 0           up_sampling2d_2[0][0]
#                                                                  block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 512)  4719104     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  2359808     activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 512)  2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 512)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 512)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 768)  0           up_sampling2d_3[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  1769728     concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 256 0           activation_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 384 0           up_sampling2d_4[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 128 442496      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 128 512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 128, 128 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 128 147584      activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 128 512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 128 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 128 0           activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256, 256, 192 0           up_sampling2d_5[0][0]
#                                                                  block1_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 256, 64) 110656      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 256, 64) 256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 256, 256, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 64) 36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 256, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 256, 256, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 3)  195         activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 256, 256, 3)  12          conv2d_13[0][0]
# __________________________________________________________________________________________________
# crfrnn (CrfRnnLayer)            [(None, 256, 256, 3) 27          batch_normalization_13[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 65536, 3)     0           crfrnn[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 65536, 3)     0           reshape_1[0][0]
# ==================================================================================================
# Total params: 48,507,306
# Trainable params: 48,497,316
# Non-trainable params: 9,990
# __________________________________________________________________________________________________

# %%
model.load_weights('/Users/mavaylon/Research/CNN_CRF/LBNL_Segmentation_crf/Notebooks/vgg_86.77_pet_class_crf.h5')

# %%
model.train(
    train_images =  "/Users/mavaylon/Research/Data1/train/img/",
    train_annotations = "/Users/mavaylon/Research/Data1/train/ann/",
    epochs=20,
    steps_per_epoch=len(glob("/Users/mavaylon/Research/Data1/train/img/*")),
    batch_size=1,
    validate=True,
    val_images="/Users/mavaylon/Research/Data1/test/img/",
    val_annotations="/Users/mavaylon/Research/Data1/test/ann/",
    val_batch_size=1,
    val_steps_per_epoch=len(glob("/Users/mavaylon/Research/Data1/test/img/*"))
)
# Out:
# Verifying training dataset
# 100%|██████████| 5912/5912 [00:20<00:00, 286.71it/s]
# Dataset verified!
# Verifying validation dataset
# 100%|██████████| 1478/1478 [00:05<00:00, 295.14it/s]
# Dataset verified!
# fit
# Epoch 1/20
# 5912/5912 [==============================] - 24702s 4s/step - loss: 0.3011 - accuracy: 0.8922 - val_loss: 0.4239 - val_accuracy: 0.8472
#
# Epoch 00001: val_accuracy improved from -inf to 0.84725, saving model to pet_class_crf.h5
# Epoch 2/20
# 5912/5912 [==============================] - 24989s 4s/step - loss: 0.2971 - accuracy: 0.8936 - val_loss: 0.3871 - val_accuracy: 0.8595
#
# Epoch 00002: val_accuracy improved from 0.84725 to 0.85949, saving model to pet_class_crf.h5
# Epoch 3/20
# 5912/5912 [==============================] - 24628s 4s/step - loss: 0.2961 - accuracy: 0.8941 - val_loss: 0.3811 - val_accuracy: 0.8635
#
# Epoch 00003: val_accuracy improved from 0.85949 to 0.86349, saving model to pet_class_crf.h5
# Epoch 4/20
# 5912/5912 [==============================] - 28460s 5s/step - loss: 0.2907 - accuracy: 0.8959 - val_loss: 0.3585 - val_accuracy: 0.8643
#
# Epoch 00004: val_accuracy improved from 0.86349 to 0.86430, saving model to pet_class_crf.h5
# Epoch 5/20
# 5912/5912 [==============================] - 26650s 5s/step - loss: 0.2874 - accuracy: 0.8969 - val_loss: 0.3670 - val_accuracy: 0.8652
#
# Epoch 00005: val_accuracy improved from 0.86430 to 0.86518, saving model to pet_class_crf.h5
# Epoch 6/20
# 5912/5912 [==============================] - 24743s 4s/step - loss: 0.2829 - accuracy: 0.8988 - val_loss: 0.3654 - val_accuracy: 0.8677
#
# Epoch 00006: val_accuracy improved from 0.86518 to 0.86768, saving model to pet_class_crf.h5
# Epoch 7/20
# 5912/5912 [==============================] - 24422s 4s/step - loss: 0.2805 - accuracy: 0.8996 - val_loss: 0.3822 - val_accuracy: 0.8701
#
# Epoch 00007: val_accuracy improved from 0.86768 to 0.87011, saving model to pet_class_crf.h5
# Epoch 8/20
# 5912/5912 [==============================] - 26799s 5s/step - loss: 0.2741 - accuracy: 0.9016 - val_loss: 0.4450 - val_accuracy: 0.8438
#
# Epoch 00008: val_accuracy did not improve from 0.87011
# Epoch 9/20
# 5912/5912 [==============================] - 24792s 4s/step - loss: 0.2708 - accuracy: 0.9028 - val_loss: 0.3864 - val_accuracy: 0.8642
#
# Epoch 00009: val_accuracy did not improve from 0.87011
# Epoch 10/20
# 5912/5912 [==============================] - 23675s 4s/step - loss: 0.2672 - accuracy: 0.9042 - val_loss: 0.3879 - val_accuracy: 0.8627
#
# Epoch 00010: val_accuracy did not improve from 0.87011
# Epoch 11/20
# 5912/5912 [==============================] - 25947s 4s/step - loss: 0.2582 - accuracy: 0.9071 - val_loss: 0.3962 - val_accuracy: 0.8613
#
# Epoch 00011: val_accuracy did not improve from 0.87011
# Epoch 12/20
# 5912/5912 [==============================] - 24510s 4s/step - loss: 0.2618 - accuracy: 0.9059 - val_loss: 0.3536 - val_accuracy: 0.8727
#
# Epoch 00012: val_accuracy improved from 0.87011 to 0.87268, saving model to pet_class_crf.h5
# Epoch 13/20
# 5912/5912 [==============================] - 39189s 7s/step - loss: 0.2539 - accuracy: 0.9086 - val_loss: 0.3869 - val_accuracy: 0.8635
#
# Epoch 00013: val_accuracy did not improve from 0.87268
# Epoch 14/20
# 5912/5912 [==============================] - 27325s 5s/step - loss: 0.2547 - accuracy: 0.9085 - val_loss: 0.4031 - val_accuracy: 0.8696
#
# Epoch 00014: val_accuracy did not improve from 0.87268
# Epoch 15/20
# 5912/5912 [==============================] - 24371s 4s/step - loss: 0.2516 - accuracy: 0.9095 - val_loss: 0.3622 - val_accuracy: 0.8738
#
# Epoch 00015: val_accuracy improved from 0.87268 to 0.87385, saving model to pet_class_crf.h5
# Epoch 16/20
# 5912/5912 [==============================] - 23505s 4s/step - loss: 0.2435 - accuracy: 0.9123 - val_loss: 0.3423 - val_accuracy: 0.8736
#
# Epoch 00016: val_accuracy did not improve from 0.87385
# Epoch 17/20
# 5912/5912 [==============================] - 23958s 4s/step - loss: 0.2381 - accuracy: 0.9140 - val_loss: 0.3784 - val_accuracy: 0.8638
#
# Epoch 00017: val_accuracy did not improve from 0.87385
# Epoch 18/20
# 5912/5912 [==============================] - 24163s 4s/step - loss: 0.2453 - accuracy: 0.9117 - val_loss: 0.3435 - val_accuracy: 0.8699
#
# Epoch 00018: val_accuracy did not improve from 0.87385
# Epoch 19/20
# 5912/5912 [==============================] - 24343s 4s/step - loss: 0.2351 - accuracy: 0.9150 - val_loss: 0.3900 - val_accuracy: 0.8756
#
# Epoch 00019: val_accuracy improved from 0.87385 to 0.87561, saving model to pet_class_crf.h5
# Epoch 20/20
# 5912/5912 [==============================] - 23848s 4s/step - loss: 0.2354 - accuracy: 0.9149 - val_loss: 0.3599 - val_accuracy: 0.8707
#
# Epoch 00020: val_accuracy did not improve from 0.87561
