# %%
import sys
sys.path.insert(1, '../Scripts')
from glob import glob
from model_utils import *
from encoders import *
from decoder import *
# Out:
# Using TensorFlow backend.
# Error in loading augmentation, can't import imgaug.Please make sure it is installed.

# %%
encoder = resnet34_encoder(input_height=512, input_width=512)
# Out:
# (None, 127, 127, 64)
# (None, 127, 127, 64)
# (None, 64, 64, 128)

# %% [markdown]
# encoder = unet_encoder(input_height=512, input_width=512, filters=[64, 128, 256, 512, 1024], channels=3, batch_norm_first=True)

# %% [markdown]
# encoder

# %%
model = resnet_unet_decoder(encoder=encoder, input_height=512, input_width=512, n_classes=3, filters=[512, 256, 128, 64, 64], depth=5, transpose=False, batch_norm_first= True, crfrnn_layer=True)

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 518, 518, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 256, 256, 64) 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 256, 256, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           bn_conv1[0][0]
# ...
