# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/Users/mavaylon/Research/Data1/train/img/2Maine_Coon_52.png', 1)

# %%
img = cv2.resize(img, (256, 256))

# %%
img = img.astype(np.float32)
img[:, :, 0] -= 103.939
img[:, :, 1] -= 116.779
img[:, :, 2] -= 123.68
img = img[:, :, ::-1]

# %%
img = img.astype(np.float32)

img.mean(axis=(0,1), dtype='float64')
# Out:
# array([122.47918701, 128.50930786, 130.75256348])

# %%
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img[:, :, 0]
# Out:
# array([[-66.68, -42.68, -48.68, ...,  35.32,  36.32,  38.32],
#        [-64.68, -32.68, -46.68, ...,  37.32,  35.32,  37.32],
#        [-64.68, -38.68, -48.68, ...,  36.32,  36.32,  35.32],
#        ...,
#        [ 76.32,  68.32,  68.32, ..., -16.68, -17.68, -27.68],
#        [ 56.32,  61.32,  67.32, ..., -58.68, -78.68, -87.68],
#        [ 72.32,  70.32,  69.32, ..., -92.68, -96.68, -99.68]],
#       dtype=float32)
